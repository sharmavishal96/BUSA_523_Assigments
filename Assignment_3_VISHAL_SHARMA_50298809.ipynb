# %% [markdown]
# Question 1: Create a class to store student records. Each student has a first name, last name,
# country, overall grade (0 - 4.0 scale), credits completed (total 30) and major.
# Create a method within this class to evaluate student progress.

# %%
class student_records:
    def input_data(self, Fname, Lname, country, overall_grade, credits_completed, smajor):
        student_records.Fname = Fname
        student_records.Lname = Lname
        student_records.country = country
        student_records.overall_grade = overall_grade
        student_records.credits_completed = credits_completed
        student_records.smajor = smajor
        
   
    def evaluate_student_progress(self):
        print("\nStudent Details is given as: ")
        print("Name: ", student_records.Fname, student_records.Lname)
        print("Country: ", student_records.country)
        print("overall grade: ", student_records.overall_grade)
        print("credits completed: ", student_records.credits_completed)
        print("Major: ", student_records.smajor)
        print("\n")
        
        if student_records.overall_grade >= 3.0 and student_records.credits_completed >= 20:
            print("Status: GOOD")
        elif (student_records.overall_grade >= 2.5 and student_records.overall_grade < 3.0) or (student_records.credits_completed >=10 and student_records.credits_completed <20):
            print("Status: AVERAGE")
        elif student_records.overall_grade < 2.5:
            print("Status: BAD")

Fname = input("Enter first name: ")
Lname = input("Enter last name: ")
country = input("Enter Country: ")
overall_grade = float(input("Enter overall grade(0 - 4.0 scale): "))
credits_completed = int(input("Enter credits completed(total 30): "))
smajor = input("Enter major: ")
            
s1 = student_records()
s1.input_data(Fname, Lname, country, overall_grade, credits_completed, smajor)

s1.evaluate_student_progress()
# Out:
# Enter first name: as
# Enter last name: as
# Enter Country: dw
# Enter overall grade(0 - 4.0 scale): 3.4
# Enter credits completed(total 30): 20
# Enter major: dwdwdq
#
# Student Details is given as:
# Name:  as as
# Country:  dw
# overall grade:  3.4
# credits completed:  20
# Major:  dwdwdq
#
#
# Status: GOOD

# %% [markdown]
# Question 2: Write a function which separates the positive and negative numbers from a
# list of numbers

# %%
input_list = []    
num =  int(input("Enter total number of input you want in the list"))
for j in range (1, num +1):
    num_list = int(input("Enter number "))
    input_list.append(num_list)

def sep_num():
        pos_list = []
        neg_list = []

        for i in range (len(input_list)):
            if input_list[i] >0:
                pos_list.append(input_list[i])
            elif input_list[i] <0:
                neg_list.append(input_list[i])
        print("Output: ", neg_list,",", pos_list)
    
sep_num()
# Out:
# Enter total number of input you want in the list5
# Enter number -1
# Enter number -3
# Enter number 4
# Enter number 5
# Enter number -7
# Output:  [-1, -3, -7] , [4, 5]

# %% [markdown]
# Question 3: Write a function which outputs all winning possibilities for a given player’s
# score. Assume the score is always between 15 and 21. Further, the dealer is
# dealt only 2 cards.

# %%
number = int(input("Enter your input(between 15 and 21): "))

def black_jack():
    combinations = []
    output = []
    for i in range (1,12):
        for j in range (i,12):
            if number < i + j < 22 :
                combinations.append(i)
                combinations.append(j)
                output.append(combinations)
                combinations = []
    print(output)
        
black_jack()
# Out:
# Enter your input(between 15 and 21): 20
# [[10, 11]]

# %% [markdown]
# Question 4: Calculate the number of steps & Big O order for the programs in question 2 and 3.

# %%
# Question 2:
'''
input_list = []    
num =  int(input("Enter total number of input you want in the list"))
for j in range (1, num +1):
    num_list = int(input("Enter number "))
    input_list.append(num_list)
    
def sep_num():                                              #number of steps = 1
        pos_list = []                                       #number of steps = 1
        neg_list = []

        for i in range (len(input_list)):                   #number of steps = 4*n
            if input_list[i] >0:
                pos_list.append(input_list[i])
            elif input_list[i] <0:
                neg_list.append(input_list[i])
        print("Output: ", neg_list,",", pos_list)           #number of steps = 1


'''
# total steps = 1 + 1 + 4*n + 1 = 3 + 4*n
# Big O is O(n)

# %%
# Question 3:
'''
number = int(input("Enter your input(between 15 and 21): ")) 

def black_jack(): 
    combinations = []                                       #number of steps = 1
    output = []                                             #number of steps = 1
    for i in range (1,12):                                  #number of steps = 5*n*n
        for j in range (i,12):                              
            if number < i + j < 22 : 
                combinations.append(i)
                combinations.append(j)
                output.append(combinations)
                combinations = []
    print(output)                                           #number of steps = 1
        
black_jack()

'''

# total steps = 1 + 1 + 5*n*n + 1 = 5*n^2 + 3
# Big O is O(n^2)
# Out:
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# [[10, 11]]
# ...
