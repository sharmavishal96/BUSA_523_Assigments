# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("C:\data.csv", index_col = 0)
data
# Out:
#             Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 5/2/10            42.31       2.572        NaN        NaN        NaN
# 12/2/10           38.51       2.548        NaN        NaN        NaN
# 19/02/2010        39.93       2.514        NaN        NaN        NaN
# 26/02/2010        46.63       2.561        NaN        NaN        NaN
# 5/3/10            46.50       2.625        NaN        NaN        NaN
# ...                 ...         ...        ...        ...        ...
# 28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 5/10/12           68.55       3.617    8077.89        NaN      18.22
# 12/10/12          62.99       3.601    2086.18        NaN       8.11
# 19/10/2012        67.97       3.594     950.33        NaN       4.93
# 26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#             MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# Date
# ...

# %% [markdown]
# Histogram

# %%
plt.hist(data["Unemployment"])
# Out:
# (array([ 4.,  0., 13., 13.,  0., 13.,  0., 38., 40., 22.]),
#  array([6.573 , 6.7263, 6.8796, 7.0329, 7.1862, 7.3395, 7.4928, 7.6461,
#         7.7994, 7.9527, 8.106 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Bar Chart

# %%
data[0 : 20][["dept_1 sales", "dept_2 sales", "dept_3 sales"]].plot.bar()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Line Chart

# %%
data[0 : 30][["dept_1 sales", "dept_2 sales", "dept_3 sales"]].plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Area Chart

# %%
data[0 : 30][["dept_1 sales", "dept_2 sales", "dept_3 sales"]].plot.area()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
#  Scatter plot

# %%
data.plot.scatter(x="Fuel_Price", y = "CPI")
# Out:
# <AxesSubplot:xlabel='Fuel_Price', ylabel='CPI'>
